# %%
#!/bin/bash


MUSIC=("/home/jack/Desktop/StoryMaker/static/music/Born_a_Rockstar-Instrumental-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/Cattle-Telecasted.mp3" "/home/jack/Desktop/StoryMaker/static/music/Bite_Me-Clean-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/El_Secreto-Yung_Logos.mp3" "/home/jack/Desktop/StoryMaker/static/music/Blue_Mood-Robert_Munzinger.mp3" "/home/jack/Desktop/StoryMaker/static/music/Escapism-Yung_Logos.mp3" "/home/jack/Desktop/StoryMaker/static/music/Enough-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/As_You_Fade_Away-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/Culture-Anno_Domini_Beats.mp3" "/home/jack/Desktop/StoryMaker/static/music/Contrast-Anno_Domini_Beats.mp3" "/home/jack/Desktop/StoryMaker/static/music/Diving_in_Backwards-Nathan_Moore.mp3" "/home/jack/Desktop/StoryMaker/static/music/Aztec_Empire-Jimena_Contreras.mp3" "/home/jack/Desktop/StoryMaker/static/music/Devil_s_Organ-Jimena_Contreras.mp3" "/home/jack/Desktop/StoryMaker/static/music/Alpha_Mission-Jimena_Contreras.mp3" "/home/jack/Desktop/StoryMaker/static/music/Changing-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/Anxiety-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/6-Shots-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/DimishedReturns.mp3" "/home/jack/Desktop/StoryMaker/static/music/Drum_Meditation.mp3" "/home/jack/Desktop/StoryMaker/static/music/ChrisHaugen.mp3" "/home/jack/Desktop/StoryMaker/static/music/DoveLove-Moreira.mp3" "/home/jack/Desktop/StoryMaker/static/music/DesertPlanet.mp3" "/home/jack/Desktop/StoryMaker/static/music/David_Fesliyan.mp3")

# Function to get a random number between 50 and 100
get_random_seconds() {
  echo $((RANDOM % 51 + 50))
}

# Function to get a random music file from the MUSIC array
get_random_music() {
  echo "${MUSIC[$((RANDOM % ${#MUSIC[@]}))]}"
}

# Get random init seconds and music file
init=$(get_random_seconds)
music=$(get_random_music)

# Run ffmpeg command
ffmpeg -hide_banner -ss "$init" -i "$music" -y Final_music.mp3

echo "The process has finished."
vlc Final_music.mp3
# Out:
# Input #0, mp3, from '/home/jack/Desktop/StoryMaker/static/music/Cattle-Telecasted.mp3':
#   Metadata:
#     encoder         : Google
#   Duration: 00:01:57.94, start: 0.025057, bitrate: 320 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 320 kb/s
#     Metadata:
#       encoder         : Lavf
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to 'Final_music.mp3':
#   Metadata:
#     TSSE            : Lavf58.29.100
#     Stream #0:0: Audio: mp3 (libmp3lame), 44100 Hz, stereo, fltp
#     Metadata:
#       encoder         : Lavc58.54.100 libmp3lame
# size=     812kB time=00:00:51.90 bitrate= 128.1kbits/s speed=39.2x
# video:0kB audio:811kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.030449%
# The process has finished.
# VLC media player 3.0.11.1 Vetinari (revision 3.0.11.1-0-g52483f3ca2)
# [0000000000714eb0] main libvlc: Running vlc with the default interface. Use 'cvlc' to use vlc without interface.
# [000000000098b8b0] alsa audio output error: cannot estimate delay: Input/output error
# QObject::~QObject: Timers cannot be stopped from another thread

# %%
#!/bin/bash


MUSIC=("/home/jack/Desktop/StoryMaker/static/music/Born_a_Rockstar-Instrumental-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/Cattle-Telecasted.mp3" "/home/jack/Desktop/StoryMaker/static/music/Bite_Me-Clean-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/El_Secreto-Yung_Logos.mp3" "/home/jack/Desktop/StoryMaker/static/music/Blue_Mood-Robert_Munzinger.mp3" "/home/jack/Desktop/StoryMaker/static/music/Escapism-Yung_Logos.mp3" "/home/jack/Desktop/StoryMaker/static/music/Enough-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/As_You_Fade_Away-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/Culture-Anno_Domini_Beats.mp3" "/home/jack/Desktop/StoryMaker/static/music/Contrast-Anno_Domini_Beats.mp3" "/home/jack/Desktop/StoryMaker/static/music/Diving_in_Backwards-Nathan_Moore.mp3" "/home/jack/Desktop/StoryMaker/static/music/Aztec_Empire-Jimena_Contreras.mp3" "/home/jack/Desktop/StoryMaker/static/music/Devil_s_Organ-Jimena_Contreras.mp3" "/home/jack/Desktop/StoryMaker/static/music/Alpha_Mission-Jimena_Contreras.mp3" "/home/jack/Desktop/StoryMaker/static/music/Changing-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/Anxiety-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/6-Shots-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/DimishedReturns.mp3" "/home/jack/Desktop/StoryMaker/static/music/Drum_Meditation.mp3" "/home/jack/Desktop/StoryMaker/static/music/ChrisHaugen.mp3" "/home/jack/Desktop/StoryMaker/static/music/DoveLove-Moreira.mp3" "/home/jack/Desktop/StoryMaker/static/music/DesertPlanet.mp3" "/home/jack/Desktop/StoryMaker/static/music/David_Fesliyan.mp3")

# Function to get a random number between 50 and 100
get_random_seconds() {
  echo $((RANDOM % 51 + 50))
}

# Function to get a random music file from the MUSIC array
get_random_music() {
  echo "${MUSIC[$((RANDOM % ${#MUSIC[@]}))]}"
}

# Get random init seconds and music file
init=$(get_random_seconds)
music=$(get_random_music)

# Run ffmpeg command
MP4="/home/jack/Desktop/HDD500/complete-videos/jpg/final5.mp4"
echo "$MP4"
ffmpeg -hide_banner -i "$MP4" -ss "$init" -i "$music" -af 'afade=in:st=0:d=4,afade=out:st=55:d=3' -map 0:0 -map 1:0 -shortest -y static/videos/Final_With_Music.mp4

echo "The process has finished."
vlc Final_With_Music.mp4
# Out:
# /home/jack/Desktop/HDD500/complete-videos/jpg/final5.mp4
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/jack/Desktop/HDD500/complete-videos/jpg/final5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:58.00, start: 0.000000, bitrate: 1100 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x640 [SAR 1:1 DAR 1:1], 1098 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Input #1, mp3, from '/home/jack/Desktop/StoryMaker/static/music/ChrisHaugen.mp3':
#   Metadata:
#     encoder         : Google
#   Duration: 00:03:26.45, start: 0.025057, bitrate: 320 kb/s
#     Stream #1:0: Audio: mp3, 44100 Hz, stereo, fltp, 320 kb/s
#     Metadata:
#       encoder         : Lavf
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (mp3 (mp3float) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55d70c39cc00] using SAR=1/1
# [libx264 @ 0x55d70c39cc00] using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2
# [libx264 @ 0x55d70c39cc00] profile High, level 3.0
# [libx264 @ 0x55d70c39cc00] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'Final_With_Music.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p(progressive), 640x640 [SAR 1:1 DAR 1:1], q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 aac
# frame= 1450 fps= 73 q=-1.0 Lsize=    8127kB time=00:00:58.00 bitrate=1147.8kbits/s speed= 2.9x
# video:7167kB audio:911kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.597132%
# [libx264 @ 0x55d70c39cc00] frame I:6     Avg QP:20.52  size: 37586
# [libx264 @ 0x55d70c39cc00] frame P:513   Avg QP:21.10  size: 11321
# [libx264 @ 0x55d70c39cc00] frame B:931   Avg QP:22.87  size:  1402
# [libx264 @ 0x55d70c39cc00] consecutive B-frames:  7.0% 18.8% 10.6% 63.7%
# [libx264 @ 0x55d70c39cc00] mb I  I16..4:  9.6% 70.3% 20.1%
# [libx264 @ 0x55d70c39cc00] mb P  I16..4:  3.5% 10.6%  1.2%  P16..4: 34.2% 11.8%  5.3%  0.0%  0.0%    skip:33.5%
# [libx264 @ 0x55d70c39cc00] mb B  I16..4:  0.1%  0.4%  0.0%  B16..8: 17.5%  1.8%  0.3%  direct: 2.1%  skip:77.7%  L0:34.4% L1:43.8% BI:21.8%
# [libx264 @ 0x55d70c39cc00] 8x8 transform intra:69.8% inter:75.0%
# [libx264 @ 0x55d70c39cc00] coded y,uvDC,uvAC intra: 45.8% 76.2% 47.0% inter: 11.7% 21.0% 4.5%
# [libx264 @ 0x55d70c39cc00] i16 v,h,dc,p: 50% 20% 16% 14%
# [libx264 @ 0x55d70c39cc00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 14% 25%  5%  6%  8%  5%  7%  5%
# [libx264 @ 0x55d70c39cc00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 14% 17%  6%  9%  9%  6%  6%  4%
# [libx264 @ 0x55d70c39cc00] i8c dc,h,v,p: 46% 17% 26% 11%
# [libx264 @ 0x55d70c39cc00] Weighted P-Frames: Y:30.0% UV:25.0%
# [libx264 @ 0x55d70c39cc00] ref P L0: 67.3% 20.1% 10.2%  2.0%  0.5%
# [libx264 @ 0x55d70c39cc00] ref B L0: 95.3%  3.9%  0.9%
# [libx264 @ 0x55d70c39cc00] ref B L1: 99.3%  0.7%
# [libx264 @ 0x55d70c39cc00] kb/s:1012.23
# [aac @ 0x55d70c39e2c0] Qavg: 133.116
# The process has finished.
# VLC media player 3.0.11.1 Vetinari (revision 3.0.11.1-0-g52483f3ca2)
# [0000000000f95eb0] main libvlc: Running vlc with the default interface. Use 'cvlc' to use vlc without interface.
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so
# libva error: /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so has no function __vaDriverInit_0_32
# libva info: va_openDriver() returns -1
# [00007f344c001840] glconv_vaapi_x11 gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/gallium_drv_video.so
# libva info: va_openDriver() returns -1
# [00007f344c001840] glconv_vaapi_drm gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/gallium_drv_video.so
# libva info: va_openDriver() returns -1
# [00007f344c001840] glconv_vaapi_drm gl error: vaInitialize: unknown libva error
# [00007f346ccb39a0] avcodec decoder: Using G3DVL VDPAU Driver Shared Library version 1.0 for hardware decoding
# [h264 @ 0x7f346ccc4680] Failed setup for format vdpau: hwaccel initialisation returned error.
# [00007f346ccb39a0] avcodec decoder error: existing hardware acceleration cannot be reused
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so
# libva error: /usr/lib/x86_64-linux-gnu/dri/nouveau_drv_video.so has no function __vaDriverInit_0_32
# libva info: va_openDriver() returns -1
# [00007f344c766310] glconv_vaapi_x11 gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/gallium_drv_video.so
# libva info: va_openDriver() returns -1
# [00007f344c766310] glconv_vaapi_drm gl error: vaInitialize: unknown libva error
# libva info: VA-API version 0.39.0
# libva info: va_getDriverName() returns 0
# libva info: Trying to open /usr/lib/x86_64-linux-gnu/dri/gallium_drv_video.so
# libva info: va_openDriver() returns -1
# [00007f344c766310] glconv_vaapi_drm gl error: vaInitialize: unknown libva error
# [h264 @ 0x7f346cd2a180] get_buffer() failed
# [h264 @ 0x7f346cd2a180] thread_get_buffer() failed
# [h264 @ 0x7f346cd2a180] decode_slice_header error
# [h264 @ 0x7f346cd2a180] no frame!
# [h264 @ 0x7f346ccc4680] get_buffer() failed
# [h264 @ 0x7f346ccc4680] thread_get_buffer() failed
# [h264 @ 0x7f346ccc4680] decode_slice_header error
# [h264 @ 0x7f346ccc4680] no frame!
# QObject::~QObject: Timers cannot be stopped from another thread

# %%
cp Final_With_Music.mp4 static/videos/Final_With_Music.mp4

# %%
/home/jack/Desktop/HDD500/complete-videos/jpg/final5.mp4

# %%
#!/bin/bash

# Print instructions for the user
echo "This script will process a video file located in the current directory."
echo "Please ensure that the 'start.mp4' file exists in this directory before proceeding."
echo "Press ENTER to continue, or CTRL+C to cancel."
read

# Check if start.mp4 exists in the current directory
if [ ! -f "start.mp4" ]; then
  echo "Error: 'start.mp4' file not found in current directory."
  exit 1
fi

# Process the video file

ffmpeg -hide_banner -i "$(pwd)/start.mp4" -filter:v "minterpolate='mi_mode=mci:mc_mode=aobmc:vsbmc=1:fps=10'" -c:v libx264 -r 20 -pix_fmt yuv420p -c:a copy -y "$(pwd)/output2.mp4"  
echo "done 1"  

ffmpeg -hide_banner -i "$(pwd)/output2.mp4" -filter:v "setpts=7*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -t 58 -y "$(pwd)/final2.mp4"
echo "done 2"   
ffmpeg -hide_banner -i "$(pwd)/final2.mp4" -filter:v "setpts=7*PTS,minterpolate='fps=25:scd=none:me_mode=bidir:vsbmc=1:search_param=200'" -t 58 -y "$(pwd)/final5.mp4"
echo "done 3"

MUSIC=("/home/jack/Desktop/StoryMaker/static/music/Born_a_Rockstar-Instrumental-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/Cattle-Telecasted.mp3" "/home/jack/Desktop/StoryMaker/static/music/Bite_Me-Clean-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/El_Secreto-Yung_Logos.mp3" "/home/jack/Desktop/StoryMaker/static/music/Blue_Mood-Robert_Munzinger.mp3" "/home/jack/Desktop/StoryMaker/static/music/Escapism-Yung_Logos.mp3" "/home/jack/Desktop/StoryMaker/static/music/Enough-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/As_You_Fade_Away-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/Culture-Anno_Domini_Beats.mp3" "/home/jack/Desktop/StoryMaker/static/music/Contrast-Anno_Domini_Beats.mp3" "/home/jack/Desktop/StoryMaker/static/music/Diving_in_Backwards-Nathan_Moore.mp3" "/home/jack/Desktop/StoryMaker/static/music/Aztec_Empire-Jimena_Contreras.mp3" "/home/jack/Desktop/StoryMaker/static/music/Devil_s_Organ-Jimena_Contreras.mp3" "/home/jack/Desktop/StoryMaker/static/music/Alpha_Mission-Jimena_Contreras.mp3" "/home/jack/Desktop/StoryMaker/static/music/Changing-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/Anxiety-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/6-Shots-NEFFEX.mp3" "/home/jack/Desktop/StoryMaker/static/music/DimishedReturns.mp3" "/home/jack/Desktop/StoryMaker/static/music/Drum_Meditation.mp3" "/home/jack/Desktop/StoryMaker/static/music/ChrisHaugen.mp3" "/home/jack/Desktop/StoryMaker/static/music/DoveLove-Moreira.mp3" "/home/jack/Desktop/StoryMaker/static/music/DesertPlanet.mp3" "/home/jack/Desktop/StoryMaker/static/music/David_Fesliyan.mp3")

# Function to get a random number between 50 and 100
get_random_seconds() {
  echo $((RANDOM % 51 + 50))
}

# Function to get a random music file from the MUSIC array
get_random_music() {
  echo "${MUSIC[$((RANDOM % ${#MUSIC[@]}))]}"
}

# Get random init seconds and music file
init=$(get_random_seconds)
music=$(get_random_music)

# Run ffmpeg command
ffmpeg -i final5.mp4 -ss "$init" -i "$music" -af 'afade=in:st=0:d=4,afade=out:st=55:d=3' -map 0:0 -map 1:0 -shortest -y Final_End.mp4

echo "The process has finished."
